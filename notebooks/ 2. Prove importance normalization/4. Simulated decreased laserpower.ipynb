# %% [markdown]
# # Simulated decreased laserpower

# %%
from skimage.io import imread
import pyclesperanto_prototype as cle
import napari
from skimage.io import imread, imshow, imsave
import pyclesperanto_prototype as cle
import numpy as np
import apoc
import matplotlib.pyplot as plt
import matplotlib

cle.select_device("Intel(R) Iris(TM) Plus Graphics 640")
# Out:
# <Intel(R) Iris(TM) Plus Graphics 640 on Platform: Apple (2 refs)>

# %% [markdown]
# ### 1.) Data selection

# %%
image_01 = imread('/Users/mara/Desktop/Bachelorarbeit/Robert - PoL/training data/overfitting_dynactin/image/img_20220520_hsp-mKate-DN-dynactin_56hpf_1_normal.tif')
imshow(image_01)

# %%
image_005 = image_01 / 2
imshow(image_005)
# Out:
# /Users/mara/opt/anaconda3/envs/devbio-napari-env5/lib/python3.9/site-packages/skimage/io/_plugins/matplotlib_plugin.py:150: UserWarning: Float image out of standard range; displaying image with stretched contrast.
#   lo, hi, cmap = _get_display_range(image)

# %%
annotation_01 = imread('/Users/mara/Desktop/Bachelorarbeit/Robert - PoL/training data/overfitting_dynactin/masks/img_20220520_hsp-mKate-DN-dynactin_56hpf_1_normal.tif')
imshow(annotation_01)
# Out:
# /Users/mara/opt/anaconda3/envs/devbio-napari-env5/lib/python3.9/site-packages/skimage/io/_plugins/matplotlib_plugin.py:150: UserWarning: Low image data range; displaying image with stretched contrast.
#   lo, hi, cmap = _get_display_range(image)

# %% [markdown]
# ### 2.) Normalization

# %%
def normalize(image):
    normalized_image = image / np.percentile(image,99)
    return normalized_image

# %%
norm_image_01 = normalize(image_01)

# %%
norm_image_005 = normalize(image_005)

# %% [markdown]
# ### 3.) Segmenter Training

# %%
# define features
features = "gaussian_blur=1 difference_of_gaussian=1 laplace_box_of_gaussian_blur=1 sobel_of_gaussian_blur=1"

# this is where the model will be saved
cl_filename = 'overfitting_segmenter_01.cl'

apoc.erase_classifier(cl_filename)
clf_01 = apoc.ObjectSegmenter(opencl_filename=cl_filename)
clf_01.train(features, annotation_01, image_01)

# %%
# this is where the model will be saved
cl_filename = 'overfitting_segmenter_norm_01.cl'

apoc.erase_classifier(cl_filename)
clf_norm_01 = apoc.ObjectSegmenter(opencl_filename=cl_filename)
clf_norm_01.train(features, annotation_01, norm_image_01)

# %% [markdown]
# ### 4.) Prediction

# %%
segmentation_result_image_01 = clf_01.predict(features=features, image=image_01)
segmentation_result_norm_image_01 = clf_norm_01.predict(features=features, image=norm_image_01)
segmentation_result_image_005 = clf_01.predict(features=features, image=image_005)
segmentation_result_norm_image_005 = clf_norm_01.predict(features=features, image=norm_image_005)

# %%
font = {'size' : 13}
matplotlib.rc('font',**font)

# %%
fig, axs = plt.subplots(2, 2, figsize=(20,10))
cle.imshow(segmentation_result_image_01, labels = True, plot=axs[0,0])
axs[0,0].set_title("image")
cle.imshow(segmentation_result_norm_image_01, labels = True, plot=axs[1,0])
axs[1,0].set_title("normalized image")
cle.imshow(segmentation_result_image_005, labels = True, plot=axs[0,1])
axs[0,1].set_title("image simulated decreased laserpower")
cle.imshow(segmentation_result_norm_image_005, labels = True, plot=axs[1,1])
axs[1,1].set_title("normalized image simulated decreased laserpower")
plt.tight_layout()

# %%
segmentation_result_image_005.max()
# Out:
# 255.0
