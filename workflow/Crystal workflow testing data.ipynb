# %% [markdown]
# # Crystal workflow

# %%
import napari
import pyclesperanto_prototype as cle
import pandas as pd

cle.select_device("Intel(R) Iris(TM) Plus Graphics 640")
# Out:
# <Intel(R) Iris(TM) Plus Graphics 640 on Platform: Apple (2 refs)>

# %% [markdown]
# ## 1.) Data selection

# %%
from library_crystals import data_selection

# %%
image_folder = "/Users/mara/Desktop/Bachelorarbeit/Rita - MPI/Pictures/images taken under same imaging conditions/"

# %%
data_selection('20220513_ET358_56hpf_2.czi',image_folder, viewer)
# Out:
# INFO:xmlschema:Resource 'XMLSchema.xsd' is already loaded
# /Users/mara/opt/anaconda3/envs/devbio-napari-env4/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# /Users/mara/opt/anaconda3/envs/devbio-napari-env4/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# Traceback (most recent call last):
# ...

# %% [markdown]
# ## 2.) Normalization

# %%
from library_crystals import normalization

# %%
input_folder = '../crystal data/6. testing data/1. images/'
normalized_folder = '../crystal data/6. testing data/2. normalized images/'

# %%
normalization(input_folder, normalized_folder)

# %% [markdown]
# ## 3.) Training of Object Segmenter

# %%
from library_crystals_testing import segmenter_testing

# %%
segmenter_testing(normalized_folder, 'object_segmenter_20220523_sorted.cl', '../crystal data/6. testing data/3. excluded small labels/')
# Out:
# img04_20220429_ET358_56hpf_4.tif
# /Users/mara/Desktop/Bachelorarbeit/Robert - PoL/napari-plugin/workflow/library_crystals_testing.py:48: UserWarning: ../crystal data/6. testing data/3. excluded small labels/img04_20220429_ET358_56hpf_4.tif is a low contrast image
#   imsave(label_folder + filename, labels_in_range)
# img07_20220513_ET358_56hpf_3.tif
# /Users/mara/Desktop/Bachelorarbeit/Robert - PoL/napari-plugin/workflow/library_crystals_testing.py:48: UserWarning: ../crystal data/6. testing data/3. excluded small labels/img07_20220513_ET358_56hpf_3.tif is a low contrast image
#   imsave(label_folder + filename, labels_in_range)
# img09_20220513_ET358_56hpf_5.tif
# /Users/mara/Desktop/Bachelorarbeit/Robert - PoL/napari-plugin/workflow/library_crystals_testing.py:48: UserWarning: ../crystal data/6. testing data/3. excluded small labels/img09_20220513_ET358_56hpf_5.tif is a low contrast image
#   imsave(label_folder + filename, labels_in_range)
# img11_20220513_ET358_56hpf_7.tif
# ...

# %% [markdown]
# ## 4.) Table generation

# %%
from library_crystals import table_generation

# %%
label_folder = '../crystal data/6. testing data/3. excluded small labels/'

# %%
table_generation(normalized_folder, label_folder, 'testing_all_measurements_normalized_image.csv')
# Out:
# img04_20220429_ET358_56hpf_4.tif
# img07_20220513_ET358_56hpf_3.tif
# img09_20220513_ET358_56hpf_5.tif
# img11_20220513_ET358_56hpf_7.tif
# img16_20220520_hsp-mKate-DN-dynactin_56hpf_3.tif
#      label  area  bbox_area  convex_area  equivalent_diameter  max_intensity  \
# 0        1   149        208          158            13.773623       3.185185
# 1        2   501        672          537            25.256544       7.370370
# 2        3  2351       6150         2918            54.711847       9.444444
# 3        4   363        532          405            21.498511       4.777778
# 4        5    60         80           62             8.740387       2.555556
# ..     ...   ...        ...          ...                  ...            ...
# 120     26    50         88           62             7.978846       1.700000
# 121     27    82         96           90            10.217908       2.600000
# 122     28   304        558          356            19.673963       3.600000
# ...

# %% [markdown]
# ## 5.) Column selection

# %%
import pandas as pd
table = pd.read_csv('testing_all_measurements_normalized_image.csv')

# %%
from library_crystals_testing import column_selection_testing

# %%
column_selection_testing(table)

# %% [markdown]
# ## 6.) Classifier

# %%
from library_crystals_testing import classifier_testing

# %%
classifier_label_folder_intensity = '../crystal data/6. testing data/4. classifier results/1. intensity/'

# %%
intensity_classifier = classifier_testing(filtered_table='testing_intensity.csv', label_folder= label_folder, tabrowcl_filename='object_classifier_20220523_intensity.cl', classifier_label_folder=classifier_label_folder_intensity, good_crystal_table_filename='testing_good_crystals_intensity.csv')
# Out:
# img04_20220429_ET358_56hpf_4.tif
# /Users/mara/Desktop/Bachelorarbeit/Robert - PoL/napari-plugin/workflow/library_crystals_testing.py:192: UserWarning: ../crystal data/6. testing data/4. classifier results/1. intensity/img04_20220429_ET358_56hpf_4.tif is a low contrast image
#   imsave(classifier_label_folder+filename, class_image)
# img07_20220513_ET358_56hpf_3.tif
# /Users/mara/Desktop/Bachelorarbeit/Robert - PoL/napari-plugin/workflow/library_crystals_testing.py:192: UserWarning: ../crystal data/6. testing data/4. classifier results/1. intensity/img07_20220513_ET358_56hpf_3.tif is a low contrast image
#   imsave(classifier_label_folder+filename, class_image)
# img09_20220513_ET358_56hpf_5.tif
# /Users/mara/Desktop/Bachelorarbeit/Robert - PoL/napari-plugin/workflow/library_crystals_testing.py:192: UserWarning: ../crystal data/6. testing data/4. classifier results/1. intensity/img09_20220513_ET358_56hpf_5.tif is a low contrast image
# ...

# %%
classifier_label_folder_size = '../crystal data/6. testing data/4. classifier results/2. size/'

# %%
size_classifier = classifier_testing(filtered_table='testing_size.csv', label_folder= label_folder, tabrowcl_filename='object_classifier_20220523_size.cl', classifier_label_folder=classifier_label_folder_size, good_crystal_table_filename='testing_good_crystals_size.csv')
# Out:
# img04_20220429_ET358_56hpf_4.tif
# /Users/mara/Desktop/Bachelorarbeit/Robert - PoL/napari-plugin/workflow/library_crystals_testing.py:192: UserWarning: ../crystal data/6. testing data/4. classifier results/2. size/img04_20220429_ET358_56hpf_4.tif is a low contrast image
#   imsave(classifier_label_folder+filename, class_image)
# img07_20220513_ET358_56hpf_3.tif
# /Users/mara/Desktop/Bachelorarbeit/Robert - PoL/napari-plugin/workflow/library_crystals_testing.py:192: UserWarning: ../crystal data/6. testing data/4. classifier results/2. size/img07_20220513_ET358_56hpf_3.tif is a low contrast image
#   imsave(classifier_label_folder+filename, class_image)
# img09_20220513_ET358_56hpf_5.tif
# /Users/mara/Desktop/Bachelorarbeit/Robert - PoL/napari-plugin/workflow/library_crystals_testing.py:192: UserWarning: ../crystal data/6. testing data/4. classifier results/2. size/img09_20220513_ET358_56hpf_5.tif is a low contrast image
#   imsave(classifier_label_folder+filename, class_image)
# ...

# %%
classifier_label_folder_shape = '../crystal data/6. testing data/4. classifier results/3. shape/'

# %%
shape_classifier = classifier_testing(filtered_table='testing_shape.csv', label_folder= label_folder, tabrowcl_filename='object_classifier_20220523_shape.cl', classifier_label_folder=classifier_label_folder_shape, good_crystal_table_filename='testing_good_crystals_shape.csv')
# Out:
# img04_20220429_ET358_56hpf_4.tif
# /Users/mara/Desktop/Bachelorarbeit/Robert - PoL/napari-plugin/workflow/library_crystals_testing.py:192: UserWarning: ../crystal data/6. testing data/4. classifier results/3. shape/img04_20220429_ET358_56hpf_4.tif is a low contrast image
#   imsave(classifier_label_folder+filename, class_image)
# img07_20220513_ET358_56hpf_3.tif
# /Users/mara/Desktop/Bachelorarbeit/Robert - PoL/napari-plugin/workflow/library_crystals_testing.py:192: UserWarning: ../crystal data/6. testing data/4. classifier results/3. shape/img07_20220513_ET358_56hpf_3.tif is a low contrast image
#   imsave(classifier_label_folder+filename, class_image)
# img09_20220513_ET358_56hpf_5.tif
# /Users/mara/Desktop/Bachelorarbeit/Robert - PoL/napari-plugin/workflow/library_crystals_testing.py:192: UserWarning: ../crystal data/6. testing data/4. classifier results/3. shape/img09_20220513_ET358_56hpf_5.tif is a low contrast image
#   imsave(classifier_label_folder+filename, class_image)
# ...

# %%
classifier_label_folder_size_intensity = '../crystal data/6. testing data/4. classifier results/4. size + intensity/'

# %%
size_intensity_classifier = classifier_testing(filtered_table='testing_size_intensity.csv', label_folder= label_folder, tabrowcl_filename='object_classifier_20220523_size_intensity.cl', classifier_label_folder=classifier_label_folder_size_intensity, good_crystal_table_filename='testing_good_crystals_size_intensity.csv')
# Out:
# img04_20220429_ET358_56hpf_4.tif
# /Users/mara/Desktop/Bachelorarbeit/Robert - PoL/napari-plugin/workflow/library_crystals_testing.py:192: UserWarning: ../crystal data/6. testing data/4. classifier results/4. size + intensity/img04_20220429_ET358_56hpf_4.tif is a low contrast image
#   imsave(classifier_label_folder+filename, class_image)
# img07_20220513_ET358_56hpf_3.tif
# /Users/mara/Desktop/Bachelorarbeit/Robert - PoL/napari-plugin/workflow/library_crystals_testing.py:192: UserWarning: ../crystal data/6. testing data/4. classifier results/4. size + intensity/img07_20220513_ET358_56hpf_3.tif is a low contrast image
#   imsave(classifier_label_folder+filename, class_image)
# img09_20220513_ET358_56hpf_5.tif
# /Users/mara/Desktop/Bachelorarbeit/Robert - PoL/napari-plugin/workflow/library_crystals_testing.py:192: UserWarning: ../crystal data/6. testing data/4. classifier results/4. size + intensity/img09_20220513_ET358_56hpf_5.tif is a low contrast image
# ...

# %%
classifier_label_folder = '../crystal data/6. testing data/4. classifier results/6. size + shape/'

# %%
size_shape_classifier = classifier_testing(filtered_table='testing_size_shape.csv', label_folder= label_folder, tabrowcl_filename='object_classifier_20220523_size_shape.cl', classifier_label_folder=classifier_label_folder, good_crystal_table_filename='testing_good_crystals_size_shape.csv')
# Out:
# img04_20220429_ET358_56hpf_4.tif
# /Users/mara/Desktop/Bachelorarbeit/Robert - PoL/napari-plugin/workflow/library_crystals_testing.py:192: UserWarning: ../crystal data/6. testing data/4. classifier results/6. size + shape/img04_20220429_ET358_56hpf_4.tif is a low contrast image
#   imsave(classifier_label_folder+filename, class_image)
# img07_20220513_ET358_56hpf_3.tif
# /Users/mara/Desktop/Bachelorarbeit/Robert - PoL/napari-plugin/workflow/library_crystals_testing.py:192: UserWarning: ../crystal data/6. testing data/4. classifier results/6. size + shape/img07_20220513_ET358_56hpf_3.tif is a low contrast image
#   imsave(classifier_label_folder+filename, class_image)
# img09_20220513_ET358_56hpf_5.tif
# /Users/mara/Desktop/Bachelorarbeit/Robert - PoL/napari-plugin/workflow/library_crystals_testing.py:192: UserWarning: ../crystal data/6. testing data/4. classifier results/6. size + shape/img09_20220513_ET358_56hpf_5.tif is a low contrast image
# ...

# %%
classifier_label_folder = '../crystal data/6. testing data/4. classifier results/6. shape + intensity/'

# %%
shape_intensity_classifier =classifier_testing(filtered_table='testing_shape_intensity.csv', label_folder= label_folder, tabrowcl_filename='object_classifier_20220523_shape_intensity.cl', classifier_label_folder=classifier_label_folder, good_crystal_table_filename='testing_good_crystals_shape_intensity.csv')
# Out:
# img04_20220429_ET358_56hpf_4.tif
# /Users/mara/Desktop/Bachelorarbeit/Robert - PoL/napari-plugin/workflow/library_crystals_testing.py:192: UserWarning: ../crystal data/6. testing data/4. classifier results/6. shape + intensity/img04_20220429_ET358_56hpf_4.tif is a low contrast image
#   imsave(classifier_label_folder+filename, class_image)
# img07_20220513_ET358_56hpf_3.tif
# /Users/mara/Desktop/Bachelorarbeit/Robert - PoL/napari-plugin/workflow/library_crystals_testing.py:192: UserWarning: ../crystal data/6. testing data/4. classifier results/6. shape + intensity/img07_20220513_ET358_56hpf_3.tif is a low contrast image
#   imsave(classifier_label_folder+filename, class_image)
# img09_20220513_ET358_56hpf_5.tif
# /Users/mara/Desktop/Bachelorarbeit/Robert - PoL/napari-plugin/workflow/library_crystals_testing.py:192: UserWarning: ../crystal data/6. testing data/4. classifier results/6. shape + intensity/img09_20220513_ET358_56hpf_5.tif is a low contrast image
# ...

# %%
classifier_label_folder = '../crystal data/6. testing data/4. classifier results/7. size + shape + intensity/'

# %%
size_shape_intensity_classifier = classifier_testing(filtered_table='testing_size_shape_intensity.csv', label_folder= label_folder, tabrowcl_filename='object_classifier_20220523_size_shape_intensity.cl', classifier_label_folder=classifier_label_folder, good_crystal_table_filename='testing_good_crystals_size_shape_intensity.csv')
# Out:
# img04_20220429_ET358_56hpf_4.tif
# /Users/mara/Desktop/Bachelorarbeit/Robert - PoL/napari-plugin/workflow/library_crystals_testing.py:192: UserWarning: ../crystal data/6. testing data/4. classifier results/7. size + shape + intensity/img04_20220429_ET358_56hpf_4.tif is a low contrast image
#   imsave(classifier_label_folder+filename, class_image)
# img07_20220513_ET358_56hpf_3.tif
# /Users/mara/Desktop/Bachelorarbeit/Robert - PoL/napari-plugin/workflow/library_crystals_testing.py:192: UserWarning: ../crystal data/6. testing data/4. classifier results/7. size + shape + intensity/img07_20220513_ET358_56hpf_3.tif is a low contrast image
#   imsave(classifier_label_folder+filename, class_image)
# img09_20220513_ET358_56hpf_5.tif
# /Users/mara/Desktop/Bachelorarbeit/Robert - PoL/napari-plugin/workflow/library_crystals_testing.py:192: UserWarning: ../crystal data/6. testing data/4. classifier results/7. size + shape + intensity/img09_20220513_ET358_56hpf_5.tif is a low contrast image
# ...
